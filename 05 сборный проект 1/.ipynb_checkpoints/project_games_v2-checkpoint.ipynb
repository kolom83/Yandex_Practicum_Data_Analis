# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px; border-radius: 10px">
#
# **Андрей, привет!** 👋
#
# Меня зовут Алексей Манелюк, я буду проверять твой проект. В Яндекс Практикуме принято общаться на "ты", но если некомфортно - скажи и перейдем на "Вы".
#
# Моя основная цель - не указать на ошибки, а поделиться опытом и помочь в освоении анализа данных.
#
# В тетрадке ты увидишь мои комментарии, пожалуйста, не удаляй, не перемещай и не изменяй их. У комментариев могут быть приписки **V2**, **V3**, **V...**, которые соответствуют каждой версии проверки.
#
# Я буду использовать цветовую разметку:
# <p>
# <div class="alert-danger" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ❌</b>
#
# Так выделены критические замечания. Без их отработки я не смогу принять проект. </div>
#
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>  Комментарий ревьюера ⚠️</b>
#
# Так выделены небольшие замечания или полезные советы. Постарайся учесть их.</div>
# <p>
# <div class="alert-success" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ✔️</b>
#
# Так выделены правильные решения.</div>
#
# Предлагаю работать в диалоге: если что-то дорабатываешь или отвечаешь на мой комментарий - пиши об этом. Мне будет удобней, если ты выделишь свои комментарии:
# <p>
# <div class="alert-info" style="padding: 20px; border-radius: 10px">
# <b>Комментарий студента 💎</b>
#
# Здесь исправил.</div>
#
# Все это поможет мне быстрее принять твой проект.</div>

# %% [markdown]
# **Описание проекта**
#
# Интернет-магазине «Стримчик» продаёт по всему миру компьютерные игры. Доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы. Нужно выявить определяющие успешность игры закономерности.
#
# Данные до 2016 года. Необходимо спланировать кампанию на 2017-й.
#
# В наборе данных есть рейтинг ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# __План исследования__
#
# Подготовка данных:
#
#     Приведение название столбцов к нижнему регистру
#     Преобразование данные в нужные типы
#     Обработка пропусков
#     Удаление дублей
#
# Исследовательский анализ данных:
#
#     Анализ продаж по годам
#     Анализ продаж по платформам
#     Исследование зависимости продаж от оценок пользователей и критиков
#     Распределение игр по жанрам
#
# Изучение региональных особенностей:
#
#     Популярность платформ
#     Различие в предпочтение  жанров
#     Влияние возрастного рейтинга
#
# Проверка гипотез

# %% [markdown]
# <div class="alert-success" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ✔️</b>
#
# Правильно, что начал проект с описания. Можно также добавить краткий план работы.</div>

# %% [markdown]
# # Шаг 1. Открытие файл с данными и изучите общую информацию

# %%
import pandas as pd
# простая библиотеа 
import matplotlib.pyplot as plt

# более продвинутая библиотека
import seaborn as sns

# подключаем библиотеку Plotly
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.graph_objs as go

init_notebook_mode(connected=True)

from scipy import stats as st

from plotly.subplots import make_subplots
from plotly.offline import iplot
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
try:
    df = pd.read_csv(r'D:\data_science\yandex_practicum\notebooks\сборный_проект_1\games.csv')
except:
    df = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# <s>А зачем здесь `try-except`, если путь к файлу одинаковый? 🤔

# %% [markdown]
# <div class="alert-info" style="padding: 20px; border-radius: 10px">
# <b>Комментарий студента 💎</b>
#
# Локально не открывается /datasets/games.csv</div>

# %%
df.shape
# Out:
# (16715, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# Таблица данных состоит из 11 колонок и 16 715 строк. Есть пропуски.
#
# У колонок с номером года и оценкой пользователей тип не соответствует данным, надо привести тип к актуальному.
#
# Много пропусков в колонках с оценками  и возрастным рейтингом. Есть пропуски в колонках год, название, жанр. Необходимо либо заполнить, либо удалить пропуски.
#
# Привести колонки в нижний регистр.

# %% [markdown]
# <div class="alert-info" style="padding: 20px; border-radius: 10px">
# <b>Комментарий студента 💎</b>
#
# Дозаполнил.</div>

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# <s>Можно чуть более подробно написать вывод по первому знакомству с данными. Типы данных, набросать план по предобработке.

# %% [markdown]
# <div class="alert-success" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ✔️</b>
#
# Данные загружены верно, получена общая информация о датафрейме. 🚀</div>

# %% [markdown]
# # Шаг 2. Подготовка данных

# %% [markdown]
# __Переименнуем колонки__

# %%
# замена названий столбцов
df = df.rename(columns={'Name':'name',
                       'Platform':'platform',
                       'Year_of_Release':'year_of_release',
                       'Genre':'genre',
                       'NA_sales':'na_sales',
                       'EU_sales':'eu_sales',
                       'JP_sales':'jp_sales',
                       'Other_sales':'other_sales',
                       'Critic_Score':'critic_score',
                       'User_Score':'user_score',
                       'Rating':'rating'})

# %%
df.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# <div class="alert-info" style="padding: 20px; border-radius: 10px">
# <b>Комментарий студента 💎</b>
#
# Этот способ более универсальные, помогает боротья с лишними пробелами в названиях. Ходя здесь все впорядке с этим.
# </div>

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# 📌 Привести названия столбцов к нижнему регистру можно так:
#
# `df.columns = df.columns.str.lower()`</div>

# %% [markdown]
# Описание данных:
#
#     •	name — название игры
#     •	platform — платформа
#     •	year_of_release — год выпуска
#     •	genre — жанр игры
#     •	na_sales — продажи в Северной Америке (миллионы проданных копий)
#     •	eu_sales — продажи в Европе (миллионы проданных копий)
#     •	jp_sales — продажи в Японии (миллионы проданных копий)
#     •	other_sales — продажи в других странах (миллионы проданных копий)
#     •	critic_score — оценка критиков (максимум 100)
#     •	user_score — оценка пользователей (максимум 10)
#     •	rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %% [markdown]
# __Приведем данные к соответствующим типам и удалим пустые строка__

# %%
# Приведем столбец с оценками пользователей к типу float, 
# а значения “tdb” (подлежит обсуждению, еще не определено) приведем к NAN.
df['user_score'] = pd.to_numeric(df['user_score'], errors='coerce')

# %%
# удаляем строки с пустыми годами
df = df.dropna(subset=['year_of_release'])

# %%
# Преобразуем тип столбца  год релиза  из float в int, а пустые заполнем нулями
df['year_of_release'] = df['year_of_release'].astype(int)

# %% [markdown]
# Записи с пропущенными годами нам не интересны, востановить их нельзя, можно указать на эти пропуски источнику данных.

# %% [markdown]
# <div class="alert-success" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ✔️</b>
#
# Согласен.

# %%
df[df['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN             1993   NaN      1.78      0.53      0.00
# 14244  NaN      GEN             1993   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score rating
# 659           0.08           NaN         NaN    NaN
# 14244         0.00           NaN         NaN    NaN

# %%
df[df['genre'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN             1993   NaN      1.78      0.53      0.00
# 14244  NaN      GEN             1993   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score rating
# 659           0.08           NaN         NaN    NaN
# 14244         0.00           NaN         NaN    NaN

# %%
df = df.dropna(subset=['name','genre'])

# %% [markdown]
# Две строки с пустым именем и жанром, можно удалить.

# %%
df.shape
# Out:
# (16444, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int32
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       7463 non-null   float64
#  10  rating           9768 non-null   object
# dtypes: float64(6), int32(1), object(4)
# memory usage: 1.4+ MB

# %%
# перебор названий столбцов в цикле и замена пропущенных значений на 'unknown'
columns_to_replace = ['rating']
for column_to_replace in columns_to_replace:
    df[column_to_replace] = df[column_to_replace].fillna('unknown')

# %% [markdown]
# <div class="alert-success" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ✔️</b>
#
# Верное решение выделить игры без рейтинга в отдельную категорию. 👍

# %% [markdown]
# <div class="alert-info" style="padding: 20px; border-radius: 10px">
# <b>Комментарий студента 💎</b>
#
# Взял пример из учебных примеров
# </div>

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# Не понял только зачем тут цикл?

# %%
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         8981
# rating                0
# dtype: int64

# %%
# создаем общую выручку от продаж игр
df['world_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['jp_sales']

# %% [markdown]
# __Удаляем дубли__

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(subset=['name', 'platform', 'year_of_release']).sum()
# Out:
# 1

# %%
display(df[df.duplicated(subset=['name', 'platform', 'year_of_release'])])
df.query('name == "Madden NFL 13" and platform == "PS3" and year_of_release == 2012')
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 16230  Madden NFL 13      PS3             2012  Sports       0.0      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating  world_sales
# 16230       0.0          0.0          83.0         5.5      E         0.01
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 604    Madden NFL 13      PS3             2012  Sports      2.11      0.22
# 16230  Madden NFL 13      PS3             2012  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating  world_sales
# 604         0.0         0.23          83.0         5.5      E         2.33
# 16230       0.0         0.00          83.0         5.5      E         0.01

# %%
df = df.drop_duplicates (subset=['name', 'platform', 'year_of_release'])

# %%
df.shape
# Out:
# (16443, 12)

# %% [markdown]
# По полям имя, платформа и год был обнаружен и удален один дубль.

# %% [markdown]
# <div class="alert-info" style="padding: 20px; border-radius: 10px">
# <b>Комментарий студента 💎</b>
#
# Строчки отличаются только значение продаж в Европе. По хорошему эти строчки надо было с хлопнуть с суммирование по полю продажи в Европе. Но не нашел подходящего метода для этого.
# </div>

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# <s>Также можно проверить наличие неявных дубликатов по сочетанию: "название игры - платформа - год".</div>

# %%
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score   rating  \
# 0     28.96      3.77         8.45          76.0         8.0        E
# 1      3.58      6.81         0.77           NaN         NaN  unknown
# 2     12.76      3.79         3.29          82.0         8.3        E
# 3     10.93      3.28         2.95          80.0         8.0        E
# 4      8.89     10.22         1.00           NaN         NaN  unknown
#
#    world_sales
# 0        77.86
# 1        46.28
# 2        36.02
# ...

# %% [markdown]
# Приведение название столбцов к нижнему регистру
#
# Преобразование данные в нужные типы
#
# Обработка пропусков
#
# Удаление дублей

# %% [markdown]
#     Около трехсот строк не имеют года выпуска, что важно для исследования, поэтому эти строки отброшены. Около половины записей не имею данные об оценках и рейтинге, что не сильно критично, заполнять их агрегированными данными не имеет смысла, оставляем как есть. Возможно эти пропуски связаны отсутствием оценок непопулярных игр.

# %% [markdown]
# <div class="alert-danger"  style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ❌</b></h5>
#
# - <s>Не хватает промежуточного вывода по разделу предобработки данных.
#
#
# - <s>Также нужно выполнить пункты задания:
#
# >Объясните, почему заполнили пропуски определённым образом или почему не стали это делать (столбцы с оценками)
# >Опишите причины, которые могли привести к пропускам;

# %% [markdown]
# <div class="alert-success" style="border-radius: 10px; padding: 20px">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Исправлено

# %% [markdown]
# # Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# __Изучаем продажи по годам__

# %%
df.groupby('year_of_release')['name'].count().plot(kind='bar', rot=90, title = 'Количество выпущенных игр по годам',
                                                  xlabel = 'год релиза', ylabel = 'количество игр');
# plt.title('Количество выпущенных игр')
# plt.xlabel('год релиза')
# plt.ylabel('количество игр');
# # plt.show()

# %% [markdown]
# <div class="alert-danger" style="padding: 20px; border-radius: 10px">
# <h5><b>Комментарий ревьюера ❌</b></h5>
#
# Пожалуйста, доработай оформление графика здесь и в остальных визуализациях проекта:
#
# 1. обязательно должен быть заголовок `plt.title('Заголовок')`
# 2. подписи осей `plt.xlabel('Заголовок оси X')` и `plt.ylabel('Заголовок оси Y')`
# 3. должны отсутствовать технические строки перед графиком, избавиться от них можно, дописав `plt.show()` в конце кода или `;`
# 4. каждый график прокомментирован хотя-бы кратко
# 5. подобран правильный размер графика

# %%
# отберем колонки sale и добавим колонку с годом
sales_df = df[[x for x in df.columns if 'sales' in x] + ['year_of_release']]
# sales_df

# %%
# сгруппируем получившуюся таблицу по годам
sales_df.groupby('year_of_release').sum().plot(#kind='bar', 
    rot=90, title = 'Количество продаж', xlabel = 'год прожаж', ylabel = 'миллионы проданных копий');
# plt.title('Количество продаж')
# plt.xlabel('год прожаж')
# plt.ylabel('миллионы проданных копий');

# %%
# посчитаем число вышедших игр и проданных копий по годам
years_df = (
    df.groupby("year_of_release")[["world_sales"]]
    .sum()
    .join(df.groupby("year_of_release")[["name"]].count())
)
# переименуем получившиеся колонки
years_df.columns = ["world_sales", "number_of_games"]
# years_df

# %%
# используем библиотеку Plotly
# создаем линию для числа проданных копий
trace0 = go.Scatter(
    x=years_df.index,
    y=years_df.world_sales,
    name='Мировые продажи'
)

# создаем линию для числа вышедших игр 
trace1 = go.Scatter(
    x=years_df.index,
    y=years_df.number_of_games,
    name='Количество выпущенных игр'
)

# определяем массив данных и задаем title графика в layout
data = [trace0, trace1]
layout = {'title': 'Статистика видео игр'}

# cоздаем объект Figure и визуализируем его
fig = go.Figure(data=data, layout=layout)
iplot(fig, show_link=False)

# %% [markdown]
# Больше всего было выпущено и продано игр в 2008 и 2009 году. До 1990 года выпускалось мало игр. Данными до 1990 года можно пренебречь. Больше всего играют в Северной Америке и в Европе.

# %% [markdown]
# <div class="alert-success" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ✔️</b>
#
# Верно, примерно до середины 90-х  игр выпускалось крайне мало, этот период можно дальше не учитывать.

# %%
# удалим записи до 1995 года
df = df.query('year_of_release >= 1995')

# %% [markdown]
# __Посмотрите, как менялись продажи по платформам.__

# %%
platforms_df = (
    df.groupby("platform")[["world_sales"]]
    .sum()
    .join(df.groupby("platform")[["name"]].count())
)
platforms_df.columns = ["world_sales", "number_of_games"]
platforms_df.sort_values("world_sales", ascending=False, inplace=True)
# platforms_df

# %%
trace0 = go.Bar(
    x=platforms_df.index, 
    y=platforms_df.world_sales, 
    name="Мировые продажи")

trace1 = go.Bar(
    x=platforms_df.index,
    y=platforms_df.number_of_games,
    name="Количество выпущенных игр",
)

data = [trace0, trace1]
layout = {"title": "Доля платформ"}

fig = go.Figure(data=data, layout=layout)

iplot(fig, show_link=False)

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# Здесь уже имеет смысл не учитывать данные до 1995 года.</div>

# %%
# выберем топ 10 наиболее прибыльных платформ и отберем по ним данные из основной таблицы
top_platform = df.groupby('platform')['world_sales'].sum().sort_values(ascending=False).nlargest(5).index.values
df_top_platform = df.query('platform in @top_platform')

# %%
# сформируем сводную талицу, где по строкам года, по колонкам платформы, в пересечении суммы продаж по миру
df_top_platform_sales = df_top_platform.pivot_table(index='year_of_release', columns = 'platform', values='world_sales', aggfunc='sum')

# %%
df_top_platform_sales.describe()
# Out:
# platform         DS         PS2         PS3         Wii        X360
# count      10.00000   12.000000   11.000000   11.000000   12.000000
# mean       91.87200   98.385833   79.650000   80.159091   74.055000
# std        67.91307   78.445254   50.807961   78.158443   53.179747
# min         1.42000    0.440000    4.530000    0.170000    1.400000
# 25%        21.82500   34.785000   32.755000    5.685000   26.482500
# 50%       117.27000   84.470000  102.800000   59.950000   84.725000
# 75%       149.95000  171.205000  115.045000  142.060000  114.520000
# max       162.66000  205.510000  149.320000  206.000000  157.910000

# %%
df_top_platform_sales.plot(grid=True, figsize=(12, 6), title = 'Динамика продаж в млн.руб. по топ-5 платформам').set(
                                     xlabel = 'год продаж', ylabel = 'объем продаж');
plt.xlim(2000, 2016)
# Out:
# (2000.0, 2016.0)

# %%
df_top_platform_sales['PS2'].plot.bar(
                    x = 'year_of_release', y = 'total_sales', grid=True, 
                    title='Объемы продаж игр на платформе PS2 (млн.копий)'
                    ).set(xlabel='год релиза', ylabel='объем продаж, млн.копий');

# %%
df_top_platform_sales['PS3'].plot.bar(
                    x = 'year_of_release', y = 'total_sales', grid=True, 
                    title='Объемы продаж игр на платформе PS3 (млн.копий)'
                    ).set(xlabel='год релиза', ylabel='объем продаж, млн.копий');

# %%
df_top_platform_sales['X360'].plot.bar(
                    x = 'year_of_release', y = 'total_sales', grid=True, 
                    title='Объемы продаж игр на платформе X360 (млн.копий)'
                    ).set(xlabel='год релиза', ylabel='объем продаж, млн.копий');

# %%
df_top_platform_sales['DS'].plot.bar(
                    x = 'year_of_release', y = 'total_sales', grid=True, 
                    title='Объемы продаж игр на платформе DS (млн.копий)'
                    ).set(xlabel='год релиза', ylabel='объем продаж, млн.копий');

# %%
df_top_platform_sales['Wii'].plot.bar(
                    x = 'year_of_release', y = 'total_sales', grid=True, 
                    title='Объемы продаж игр на платформе Wii (млн.копий)'
                    ).set(xlabel='год релиза', ylabel='объем продаж, млн.копий');

# %% [markdown]
# В среднем версии популярных игровых платформ живут около десяти лет.

# %% [markdown]
# Лидерами продаж являются PlayStation, Xbox, Nintendo, Wii. В среднем версия игровой платформы живет около десяти лет. Для прогноза на 2017 год с учетом, что за 2016 год данные могут быть неполными, достаточно взять данные с 2014 года включительно.

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# <s>Я бы сказал немного побольше - порядка 10-ти лет. Срок жизни платформы можно оценить по взлету и падению суммарных продаж по годам.
#
# Более наглядно представить на графиках можно, если вывести динамику по годам нескольких наиболее популярных платформ, которые прошли пик популярности.

# %% [markdown]
# __Найдем потенциально перспективные платформы__

# %%
# отберем данные за последнии 3 года
df_relevant = df.query('year_of_release >= 2014')
df_relevant.shape
# Out:
# (1689, 12)

# %% [markdown]
# <div class="alert-success" style="border-radius: 10px; padding: 20px">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Теперь актуальный период выбран правильно.

# %% [markdown]
# <div class="alert-danger" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ❌</b></h5>
#
# <s>Стоит взять актуальный период для анализа и прогноза немного посовременней. Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как видеоигры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. </div>

# %%
top_platform_relevant = df_relevant.groupby('platform')['world_sales'].sum().sort_values(ascending=False).nlargest(5).index.values
df_top_platform_relevant = df_relevant.query('platform in @top_platform_relevant')

# %%
df_top_platform_relevant.pivot_table(index='year_of_release', columns = 'platform', values='world_sales', aggfunc='sum')\
    .plot(#kind='bar', 
    rot = 90,
    title = 'Количество продаж',
    xlabel = 'год прожаж',
    ylabel = 'миллионы проданных копий');

# %% [markdown]
# За последние время наметилась общая тенденция к снижению продаж игр на всех игровых платформах.
#
# Лидерами продаж к 2016 году являются PS4, XOne, 3DS. И хотя наибольшие продажи за последние 7 лет были у PS3, X360, Wii, время этих платформ проходит и вряд ли они будут лидерами продаж в будущем.

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# Добавь пожалуйста подзаголовки в свою работу, в соответсвии с вопросами задания.</div>

# %%
ax = sns.boxplot(y="world_sales", x="platform", data=df_top_platform_relevant.query('platform in @top_platform_relevant'))
ax.set(ylim=(0,2))

# Добавляем заголовок
ax.set_title('Распределение продаж по платформам')

# Добавляем подпись к оси x
ax.set_xlabel('платформы')

# Добавляем подпись к оси y
ax.set_ylabel('продажи')

# Отображаем график
plt.show()

# %%
data = []
for platform in top_platform_relevant:
    data.append(
        go.Box(
            y=df_top_platform_relevant.query('platform == @platform and year_of_release >= 2014 and year_of_release < 2017').world_sales,
            name=platform,
            boxpoints='all',  # Отобразить все точки данных
            boxmean=True # Растянуть график
        )
    )


# Создаем подграфик с одной строкой и одним столбцом
fig = make_subplots(rows=1, cols=1)

# Добавляем box plot в подграфик
for trace in data:
    fig.add_trace(trace)
    
fig.update_yaxes(range=[0, 1.5])

# Обновляем заголовок и подписи осей
fig.update_layout(title_text='Распределение продаж по платформа',
                  xaxis_title='платформы',
                  yaxis_title='продажи')

# Визуализация данных
iplot(fig, show_link=False)

# %% [markdown]
# У каждой платформы были топвые игры, которые тянули продажи в рамках платформы вверх.
#
# Лидерами продаж являются PS4, XOne, WiiU.
#
# И хотя продажи были так же большими у PS3, 3DS, формировались они за счет отдельных игр. Средние продажи по играм у них ниже, время этих платформ проходит и вряд ли они будут лидерами продаж в будущем.

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# <s>На таком графике довольно сложно сравнить медианы и межквартильный размах. Имеет смысл ограничить диапазон выбросов.
#
# Ось можно вытянуть параметром `ylim`.</div>

# %% [markdown]
# <div class="alert-info" style="padding: 20px; border-radius: 10px">
# <b>Комментарий студента 💎</b>
# Теперь рассмотрел медиану и размах. Но что-то с plotly.graph_objs не получилась тоже самое сделать. Код выше сгенерирывал ИИ, как он работает не пойму.</div>

# %% [markdown]
# __Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков.__

# %%
ax = sns.regplot(x="user_score", y="world_sales", data=df_relevant[df_relevant.platform == 'PS4']);

# Добавляем заголовок
ax.set_title('Завсимость продаж от оценок пользователей')

# Добавляем подпись к оси x
ax.set_xlabel('оценки')

# Добавляем подпись к оси y
ax.set_ylabel('продажи')

# Отображаем график
plt.show()

# %%
ax = sns.regplot(x="critic_score", y="world_sales", data=df_relevant[df_relevant.platform == 'PS4']);
# Добавляем заголовок
ax.set_title('Завсимость продаж от оценок критиков')

# Добавляем подпись к оси x
ax.set_xlabel('оценки')

# Добавляем подпись к оси y
ax.set_ylabel('продажи')

# Отображаем график
plt.show()

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# <s>Закомментированный полностью код лучше удалить из финальной версии проекта.

# %%
# подсчет корреляции
correlation = df_relevant[df_relevant.platform == 'PS4']['user_score'].corr(df_relevant[df_relevant.platform == 'PS4']['world_sales'])
print(f'Корреляция между отзывами пользователей и продажами: {correlation}')
# Out:
# Корреляция между отзывами пользователей и продажами: -0.030189376309048967

# %%
correlation = df_relevant[df_relevant.platform == 'PS4']['critic_score'].corr(df_relevant[df_relevant.platform == 'PS4']['world_sales'])
print(f'Корреляция между отзывами критиков и продажами: {correlation}')
# Out:
# Корреляция между отзывами критиков и продажами: 0.40762835187815405

# %%
# отберем строки с числовым типом
features = list(set(['world_sales', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'critic_score', 'user_score']))

# %%
# corr_matrix = df_relevant[df_relevant.platform == 'PS4'][features].drop(['name', 'platform', 'year_of_release', 'genre', 'rating'], axis = 1).corr()
corr_matrix = df_relevant[df_relevant.platform == 'PS4'][features].corr()
corr_matrix
# Out:
#               na_sales  world_sales  jp_sales  other_sales  user_score  \
# na_sales      1.000000     0.923267  0.491452     0.944903   -0.016156
# world_sales   0.923267     1.000000  0.576995     0.995192   -0.030189
# jp_sales      0.491452     0.576995  1.000000     0.510433    0.179384
# other_sales   0.944903     0.995192  0.510433     1.000000   -0.044166
# user_score   -0.016156    -0.030189  0.179384    -0.044166    1.000000
# eu_sales      0.784902     0.957147  0.472101     0.944380   -0.064199
# critic_score  0.411638     0.407628  0.379041     0.404645    0.546434
#
#               eu_sales  critic_score
# na_sales      0.784902      0.411638
# world_sales   0.957147      0.407628
# jp_sales      0.472101      0.379041
# other_sales   0.944380      0.404645
# user_score   -0.064199      0.546434
# eu_sales      1.000000      0.340268
# critic_score  0.340268      1.000000

# %%
# построим тепловую карту корреляции числовых показателей
ax = sns.heatmap(corr_matrix)
# Добавляем заголовок
ax.set_title('Тепловая карта корреляции числовых показателей')

# Отображаем график
plt.show()

# %% [markdown]
# Продажи практически не коррелируются с оценкой пользователей и положительно коррелируются с оценкой критиков с коэффициентом около 0,4. Важнее для продаж оценка профессиональных экспертов, чем пользователей. Возможно при начале продаж оценок пользователей еще мало, и покупатели ориентируются больше на экспертные оценки.

# %% [markdown]
# <div class="alert-success" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ✔️</b>
#
# Верно, на PS4 оценки критиков сильнее влияют на успешность игры.</div>

# %%
ax = sns.regplot(x="critic_score", y="world_sales", data=df_relevant[df_relevant.platform == 'XOne'])
# Добавляем заголовок
ax.set_title('Зависимость продаж XOne от оценки критиков')

# Добавляем подпись к оси x
ax.set_xlabel('Оценка')

# Добавляем подпись к оси y
ax.set_ylabel('продажи, млн.копий')

# Отображаем график
plt.show()

ax = sns.regplot(x="user_score", y="world_sales", data=df_relevant[df_relevant.platform == 'XOne'])
# Добавляем заголовок
ax.set_title('Зависимость продаж XOne от оценки пользователей')

# Добавляем подпись к оси x
ax.set_xlabel('Оценка')

# Добавляем подпись к оси y
ax.set_ylabel('продажи, млн.копий')

# Отображаем график
plt.show()

# подсчет корреляции
correlation = df_relevant[df_relevant.platform == 'XOne']['user_score'].corr(df_relevant[df_relevant.platform == 'XOne']['world_sales'])
print(f'Корреляция между отзывами пользователей и продажами: {correlation}')
correlation = df_relevant[df_relevant.platform == 'XOne']['critic_score'].corr(df_relevant[df_relevant.platform == 'XOne']['world_sales'])
print(f'Корреляция между отзывами критиков и продажами: {correlation}')
# Out:
# Корреляция между отзывами пользователей и продажами: -0.06980695488621874
# Корреляция между отзывами критиков и продажами: 0.4287656579111681

# %%
ax = sns.regplot(x="critic_score", y="world_sales", data=df_relevant[df_relevant.platform == '3DS'])
ax.set_title('Зависимость продаж 3DS от оценки критиков')

# Добавляем подпись к оси x
ax.set_xlabel('Оценка')

# Добавляем подпись к оси y
ax.set_ylabel('продажи, млн.копий')

# Отображаем график
plt.show()

ax = sns.regplot(x="user_score", y="world_sales", data=df_relevant[df_relevant.platform == '3DS']);
ax.set_title('Зависимость продаж 3DS от оценки пользователей')

# Добавляем подпись к оси x
ax.set_xlabel('Оценка')

# Добавляем подпись к оси y
ax.set_ylabel('продажи, млн.копий')

# Отображаем график
plt.show()

# подсчет корреляции
correlation = df_relevant[df_relevant.platform == '3DS']['user_score'].corr(df_relevant[df_relevant.platform == '3DS']['world_sales'])
print(f'Корреляция между отзывами пользователей и продажами: {correlation}')
correlation = df_relevant[df_relevant.platform == '3DS']['critic_score'].corr(df_relevant[df_relevant.platform == '3DS']['world_sales'])
print(f'Корреляция между отзывами критиков и продажами: {correlation}')
# Out:
# Корреляция между отзывами пользователей и продажами: 0.22681424762431077
# Корреляция между отзывами критиков и продажами: 0.30543454266947156

# %% [markdown]
# Продажи практически не коррелируются с оценкой пользователей, есть не большая корреляция у платформы 3DS. Но в области больших оценок и больше выбросов по продажам. Есть небольшая положительная корреляция с оценкой критиков с коэффициентом около 0,4. Надо помнить о большом количестве пропусков в колонках оценок, возможно не популярные игры и не оценивают.

# %% [markdown]
# <div class="alert-success" style="border-radius: 10px; padding: 20px">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Согласен с выводом.

# %% [markdown]
# <div class="alert-danger" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ❌</b></h5>
#
# <s>Здесь нужно посмотреть корреляцию оценок с общими продажами, задачи анализировать корреляции в разрезе регионов у нас нет.
#
# Также, нужно сравнить не все платформы скопом, а посмотреть несколько популярных платформ по отдельности - у каждой могут быть в этом отношении свои особенности.
#
# Давай добавим структуры в этот раздел. PS4 ты рассмотрел, теперь давай добавим еще пару-тройку популярных платформ, например XOne и 3DS и по каждой добавим:
#
# - Диаграммы рассеяния
# - Коэффиценты корреляции
# - Вывод

# %% [markdown]
# __Распределение игр по жанрам__

# %%
# возвращает данные в заданном квантиле
# df.genre.quantile(q=0.5, interpolation='linear')
df.genre.unique()
# Out:
# array(['Sports', 'Racing', 'Role-Playing', 'Platform', 'Misc',
#        'Simulation', 'Action', 'Puzzle', 'Shooter', 'Fighting',
#        'Adventure', 'Strategy'], dtype=object)

# %%
df.groupby('genre')['name'].count().sort_values(ascending=False).plot(kind='bar', rot=90,
                                                                     title = 'Выпуски игр по жанрам',
                                                                     xlabel='Жанр',
                                                                     ylabel='продажи, млн.копий')
plt.show()

# %%
df.groupby('genre')['world_sales'].sum().sort_values(ascending=False).plot(kind='bar', rot=90,
                                                                          title = 'Продажи по жанрам',
                                                                          xlabel='Жанр',
                                                                          ylabel='продажи, млн.копий')
plt.show()

# %%
genre_df = (
    df.groupby("genre")[["world_sales"]]
    .sum()
    .join(df.groupby("genre")[["name"]].count())
)
genre_df.columns = ["world_sales", "number_of_games"]
genre_df.sort_values("world_sales", ascending=False, inplace=True)
genre_df.columns
# Out:
# Index(['world_sales', 'number_of_games'], dtype='object')

# %%
trace0 = go.Bar(
    x=genre_df.index, 
    y=genre_df.world_sales, 
    name="Мировые продажи")

trace1 = go.Bar(
    x=genre_df.index,
    y=genre_df.number_of_games,
    name="Количество выпущенных игр",
)

data = [trace0, trace1]
layout = {"title": "Доля жанров"}

fig = go.Figure(data=data, layout=layout)

iplot(fig, show_link=False)

# %% [markdown]
# Самые популярные и продаваемые игры, это экшен, спорт, ролевые игры  (ходилки, бролилки, стрелялки от первого лица), не самые продаваемые - головоломки, стратегии. Напрягать мозги лишний раз желающих мало, а вот побегать, хоть виртуально, много.

# %% [markdown]
# <div class="alert-danger" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ❌</b></h5>
#
# <s>Ты правильно определил лидеров и аутсайдеров по суммарным продажам и количеству выпущенных игр. Но также в задании требуется определить наиболее прибыльный жанр.
#
# Обрати внимание, что общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние или медианные продажи.</div>

# %%
data_ = df.query('2014 <= year_of_release <= 2016').groupby("genre")[["world_sales"]].mean().sort_values("world_sales", ascending=False)
data_.head().index
# Out:
# Index(['Shooter', 'Sports', 'Role-Playing', 'Fighting', 'Platform'], dtype='object', name='genre')

# %%
genre_df.columns = ["world_sales", "number_of_games"]

# %%
data_.plot(kind='bar', rot=90, title = 'Среднее количество выпущенных игр в жанре',
                                                  xlabel = 'жанры', ylabel = 'среднее количество игр');

# %% [markdown]
# <div class="alert-info" style="padding: 20px; border-radius: 10px">
# <b>Комментарий студента 💎</b>
# С помощью библиотеки Seaborn не получилось. Есть критерий, ккогда использовать Seaborn или Plotly, или функцию plot? Или это все индивидуально?
# </div>

# %% [markdown]
# <div class="alert-warning" style="border-radius: 10px; padding: 20px">
# <b>Комментарий ревьюера V2 ⚠️</b>
#
# График не очень наглядный, стоит использовать столбчатую диаграмму средних продаж, отсортированную по убыванию.

# %% [markdown]
# За последние 3 года лидерами являются  'Shooter', 'Sports', 'Role-Playing', 'Fighting', 'Platform'.
#
# По среднему объему продаж лидерство у жанра 'Shooter', 'Sports', 'Role-Playing', 'Fighting', 'Platform'. Жанр Action менее стабилен в продажах и имеет наибольшее количество выбросов, лидирует в основном за счет небольшого количества игр.

# %% [markdown]
# # Шаг 4. Составьте портрет пользователя каждого региона

# %% [markdown]
# __Популярные платформы в регионльном разрезе__

# %%
platform_df_region = (
    df_top_platform_relevant.groupby("platform")[["na_sales", 'eu_sales', 'jp_sales', 'world_sales']].sum()
    
)
platform_df_region['fr_na_sales'] = platform_df_region['na_sales']/platform_df_region['world_sales']
platform_df_region['fr_eu_sales'] = platform_df_region['eu_sales']/platform_df_region['world_sales']
platform_df_region['fr_jp_sales'] = platform_df_region['jp_sales']/platform_df_region['world_sales']

# %%
trace0 = go.Bar(
    x=platform_df_region.sort_values('fr_na_sales', ascending=False).index, 
    y=platform_df_region.sort_values('fr_na_sales', ascending=False).fr_na_sales, 
    name="Продажи в северной Америке")

# %%
trace1 = go.Bar(
    x=platform_df_region.sort_values('fr_eu_sales', ascending=False).index,
    y=platform_df_region.sort_values('fr_eu_sales', ascending=False).fr_eu_sales,
    name="Продажи в Европе",
)

# %%
trace2 = go.Bar(
    x=platform_df_region.sort_values('fr_jp_sales', ascending=False).index,
    y=platform_df_region.sort_values('fr_jp_sales', ascending=False).fr_jp_sales,
    name="Продажи в Японии",
)

# %%
data = [trace0]
layout = {"title": "Доля платформ по северной Америке"}

fig = go.Figure(data=data, layout=layout)

iplot(fig, show_link=False)


data = [trace1]
layout = {"title": "Доля платформ по Европе"}

fig = go.Figure(data=data, layout=layout)

iplot(fig, show_link=False)

data = [trace2]
layout = {"title": "Доля платформ по Японии"}

fig = go.Figure(data=data, layout=layout)

iplot(fig, show_link=False)

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# <s>Информативнее будет вывести три графика в ряд: отдельно по каждому региону.

# %% [markdown]
# В Японии популярны портативные игровые платформы 3DS, в Северной Америке предпочитают платформы Wii и XOne от Американской компании Microsoft, в Европе больше распространены PlayStation.

# %% [markdown]
# __Популярные жанры в регионльном разрезе__

# %%
top_genre_relevant = df_relevant.groupby('genre')['world_sales'].mean().sort_values(ascending=False).nlargest(5).index.values

# %%
genre_df_region = (
    df_relevant[df_relevant['genre'].isin(top_genre_relevant)].groupby("genre")[["na_sales", 'eu_sales', 'jp_sales', 'world_sales']].sum()
    
)

# %%
trace0 = go.Bar(
    x=genre_df_region.sort_values('na_sales', ascending=False).index, 
    y=genre_df_region.sort_values('na_sales', ascending=False).na_sales, 
    name="Продажи в северной Америке")

trace1 = go.Bar(
    x=genre_df_region.sort_values('eu_sales', ascending=False).index,
    y=genre_df_region.sort_values('eu_sales', ascending=False).eu_sales,
    name="Продажи в Европе",
)

trace2 = go.Bar(
    x=genre_df_region.sort_values('jp_sales', ascending=False).index,
    y=genre_df_region.sort_values('jp_sales', ascending=False).jp_sales,
    name="Продажи в Японии",
)

data = [trace0]
layout = {"title": "Доля жанров по Америке"}

fig = go.Figure(data=data, layout=layout)

iplot(fig, show_link=False)

data = [trace1]
layout = {"title": "Доля жанров по Европе"}

fig = go.Figure(data=data, layout=layout)

iplot(fig, show_link=False)

data = [trace2]
layout = {"title": "Доля жанров по Японии"}

fig = go.Figure(data=data, layout=layout)

iplot(fig, show_link=False)

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# <s>Здесь тоже, стоит отобразить топ-5 по каждому региону отдельно.

# %% [markdown]
# В Америке и Европе больше популярны экшен, спортивные симуляторы и  «стрелялки», в Японии предпочитают Ролевые игры, что во многом связано с культурой этих регионов.

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# <s>В целом, подход у тебя правильный, но из-за широких границ актуального периода в результаты попали устаревшие платформы, ориентироваться на них при планировании рекламной кампании заказчику нельзя.
#
# Аналогично и жанры нужно рассматривать в рамках актуального периода.</div>

# %% [markdown]
# <div class="alert-success" style="border-radius: 10px; padding: 20px">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Портреты игроков по платформам и жанрам построены правильно.
#
# 💡 Обычно категории на таких графиках сортируются по убыванию.

# %% [markdown]
# __Влияние рейтинга ESRB на продажи в отдельном регионе__

# %%
df_relevant.rating.unique()
# Out:
# array(['unknown', 'M', 'E', 'T', 'E10+'], dtype=object)

# %%
rating_df_region = (
    df_relevant.groupby("rating")[["na_sales", 'eu_sales', 'jp_sales']].sum()
)
rating_df_region
# Out:
#          na_sales  eu_sales  jp_sales
# rating
# E           50.74     58.06      8.94
# E10+        33.23     26.16      4.46
# M           96.42     93.44      8.01
# T           38.95     34.07     14.78
# unknown     64.72     58.95     56.90

# %%
rating_df_region['fr_na_sales'] = (rating_df_region['na_sales']/rating_df_region['na_sales'].sum()*100).round(2)
rating_df_region['fr_eu_sales'] = (rating_df_region['eu_sales']/rating_df_region['eu_sales'].sum()*100).round(2)
rating_df_region['fr_jp_sales'] = (rating_df_region['jp_sales']/rating_df_region['jp_sales'].sum()*100).round(2)
rating_df_region
# Out:
#          na_sales  eu_sales  jp_sales  fr_na_sales  fr_eu_sales  fr_jp_sales
# rating
# E           50.74     58.06      8.94        17.86        21.45         9.60
# E10+        33.23     26.16      4.46        11.70         9.66         4.79
# M           96.42     93.44      8.01        33.94        34.52         8.60
# T           38.95     34.07     14.78        13.71        12.59        15.88
# unknown     64.72     58.95     56.90        22.78        21.78        61.12

# %%
trace0 = go.Bar(
    x=rating_df_region.index, 
    y=rating_df_region.fr_na_sales, 
    name="Продажи в Северной Америке")

trace1 = go.Bar(
    x=rating_df_region.index,
    y=rating_df_region.fr_eu_sales,
    name="Продажи в Европе",
)

trace2 = go.Bar(
    x=rating_df_region.index,
    y=rating_df_region.fr_jp_sales,
    name="Продажи в Японии",
)

data = [trace0, trace1, trace2]
layout = {"title": "Процент игр с разным рейтингом по регионам"}

fig = go.Figure(data=data, layout=layout)

iplot(fig, show_link=False)

# %% [markdown]
# Продажи игр без рейтинга примерно одинаковы в разных регионах. Продажи игры с рейтингом различаются в зависимости от региона. В Северной Америке и Европе популярны игры с рейтингом «М» (для взрослых), в Японии популярны игры с рейтингом «Т» (для всех) и «Е» (для подростков).

# %% [markdown]
# <div class="alert-danger" style="padding: 20px; border-radius: 10px">
# <h5><b>Комментарий ревьюера ❌</b></h5>
#
# При таком способе подсчета игры без рейтинга оказываются полностью исключенными из анализа. Но продажи именно этих игр могут указать на ключевое различие в регионах.</div>

# %% [markdown]
# <div class="alert-danger" style="padding: 20px; border-radius: 10px">
# <h5><b>Комментарий ревьюера V2 ❌</b></h5>
#
# Проверь пожалуйста сортировки, у меня получается другая картина по Японии, кроме того по заданию, нужно отобразить топ-5 жанров.

# %% [markdown]
# <div class="alert-info" style="padding: 20px; border-radius: 10px">
# <b>Комментарий студента 💎</b>
# Не удачно выбрал график и надо было выводить относительные данные (процент), а не абсолютные (количество продаж).
# </div>

# %%
ax = rating_df_region['fr_na_sales'].sort_values(ascending=False).plot(kind='bar', rot=90, title = 'Процет выпущенных игр по жанрам в Северной Америке',
                                                  xlabel = 'жанры', ylabel = 'процент игр');

for p in ax.patches:
    height = p.get_height()/2
    ax.annotate(f"{p.get_height():.2f}%", (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', rotation='vertical')

plt.show()

# %%
ax = rating_df_region['fr_eu_sales'].sort_values(ascending=False).plot(kind='bar', rot=90, title = 'Процент выпущенных игр по жанрам в Европе',
                                                  xlabel = 'жанры', ylabel = 'процент игр');

for p in ax.patches:
    height = p.get_height()/2
    ax.annotate(f"{p.get_height():.2f}%", (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', rotation='vertical')

# Отображаем график
plt.show()

# %%
ax = rating_df_region['jp_sales'].sort_values(ascending=False).plot(kind='bar', rot=90, title = 'Процент выпущенных игр по жанрам в Японии',
                                                  xlabel = 'жанры', ylabel = 'процент игр');

for p in ax.patches:
    height = p.get_height()/2
    ax.annotate(f"{p.get_height():.2f}%", (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', rotation='vertical')

# Отображаем график
plt.show()

# %%
#Код ревьюера
ax = df_relevant.groupby('rating')['jp_sales'].sum()\
    .plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8))
ax.set_title('Рейтинг ESRB в Японии')
ax.set_ylabel(None)
plt.show()

# %% [markdown]
# <div class="alert-info" style="padding: 20px; border-radius: 10px">
# <b>Комментарий студента 💎</b>
# Что-то проценты не сошлись :)
# </div>

# %% [markdown]
# # Шаг 5. Проверьте гипотезы

# %% [markdown]
# __Проверим гипотезу о равенстве пользовательски оценок для двух платформ__

# %%
user_score_XOne = df.query('platform == "XOne"').user_score.dropna()
user_score_XOne.mean()
# Out:
# 6.521428571428572

# %%
user_score_PC = df.query('platform == "PC"').user_score.dropna()
user_score_PC.mean()
# Out:
# 7.072606382978724

# %% [markdown]
# Нулевая гипотеза, что средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
# Альтернативная гипотеза: средние пользовательского ретинга отличается.
#
# Две независимые выборки, метод «scipy.stats.ttest_ind».

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# <s>Формулировка альтернативной гипотезы должна быть противоположной нулевой. Например здесь: "Средние пользовательские рейтинги платформ Xbox One и PC различаются".

# %%
alpha = 0.05# задайте уровень стат. значимости

results = st.ttest_ind(user_score_XOne, user_score_PC,
                        # alternative='greater',
                        # alternative='less'
                      )

# выведите на экран получившееся p-значение
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу о равенстве средней пользовательской оценки двух платформ')
else:
    print('Не получилось отвергнуть нулевую гипотезу о равенстве средней пользовательской оценки двух платформ')
# Out:
# p-значение: 9.379956219356061e-06
# Отвергаем нулевую гипотезу о равенстве средней пользовательской оценки двух платформ

# %% [markdown]
# Средний рейтинг этих платформ не одинаков.

# %% [markdown]
# <div class="alert-success" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ✔️</b>
#
# Результат проверки гипотезы правильный.

# %% [markdown]
# __Проверим гипотезу о равенстве пользовательских оценок для двух жанров__

# %%
user_score_Action = df.query('genre == "Action"').user_score.dropna()
user_score_Action.mean()
# Out:
# 7.058129175946549

# %%
user_score_Sports = df.query('genre == "Sports"').user_score.dropna()
user_score_Sports.mean()
# Out:
# 6.9527777777777775

# %% [markdown]
# Проверим гипотезу: средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Нулевая гипотеза: средние пользовательские рейтинги жанров одинаковы.
#
# Альтернативная гипотеза средний пользовательский рейтинг жанра Action и рейтинга жанра Sports различаются.

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# <s>По заданию, нужно проверить двустороннюю гипотезу о неравенстве рейтингов.

# %%
alpha = 0.05# задайте уровень стат. значимости

results = st.ttest_ind(user_score_Action, user_score_Sports, 
                         # alternative='greater',
                         # alternative='less'
                      )

# выведите на экран получившееся p-значение
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.06833686503882228
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Результат: не получилось отвергнуть нулевую гипотезу: средние пользовательских рейтингов жанров Action и Sports совпадают.

# %% [markdown]
# <div class="alert-success" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера V2 ✔️</b>
#
# Гипотезы проверены правильно.

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# <s>Промежуточные выводы целесообразно поместить в конце соответствующего раздела работ.

# %% [markdown]
# __Шаг 6. Общий вывод__
#
# Представлены данные о выпусках и продажах компьютерных игр по годам с данными о продажах, оценках критиков и пользователей, возрастном рейтинге. Около трехсот строк не имеют года выпуска, что важно для исследования, поэтому эти строки отброшены. Около половины записей не имею данные об оценках и рейтинге, что не сильно критично, заполнять их агрегированными данными не имеет смысла, оставляем как есть.
#
# Исследование показало, что основной выпуск и продажи игр пришлись на нулевые и десятые годы. Лидерами продаж являются PlayStation, Xbox, Nintendo, Wii. В среднем версия игровой платформы живет около десяти лет.
#
# За последние время наметилась общая тенденция к снижению продаж игр на всех игровых платформах. Лидерами продаж к 2016 году являются PS4, XOne, 3DS. И хотя наибольшие продажи за последние 7 лет были у PS3, X360, Wii, время этих платформ проходит и вряд ли они будут лидерами продаж в будущем.
#
# У каждой платформы были топвые игры, которые тянули продажи в рамках платформы вверх, и хотя продажи были так же большими у PS3, 3DS, формировались они за счет отдельных игр. Средние продажи по играм у них ниже чем у лидеров, время этих платформ проходит и вряд ли они будут лидерами продаж в будущем.
#
# Продажи практически не коррелируются с оценкой пользователей, есть не большая корреляция у платформы 3DS. Но в области больших оценок наблюдаются больше выбросов по продажам, пользовательские оценки характерны для топовых игр. Есть небольшая положительная корреляция с оценкой критиков с коэффициентом около 0,4. Надо помнить о большом количестве пропусков в колонках оценок, возможно не популярные игры и не оценивают.
#
# В отношении жанров за последние 3 года лидерами являются  Shooter, Action, Sports, Role-Playing. Но если посмотреть статистические данные, то по ширине межквартильного интервала, медиане и среднему объему продаж лидерство у жанра Shooter, Sport, Role-Playing. Жанр Action менее стабилен в продажах и имеет наибольшее количество выбросов, лидирует в основном за счет небольшого количества топ-игр.
#
# Региональные различия касаются как платформ, так и жанров.
# В Японии популярны портативные игровые платформы 3DS, в Северной Америке предпочитают платформы Wii и XOne от Американской компании Microsoft, в Европе больше распространены PlayStation.
#
# В Америке и Европе больше популярны шутеры, спортивные симуляторы и  «стрелялки», в Японии предпочитают Ролевые игры, что во многом связано с культурой этих регионов.
#
# Продажи игр без рейтинга примерно одинаковы в разных регионах. Продажи игры с рейтингом различаются в зависимости от региона. В Северной Америке и Европе популярны игры с рейтингом «М» (для взрослых), в Японии популярны игры с рейтингом «Т» (для всех) и «Е» (для подростков).
#
# Гипотезы
# Гипотеза о равенстве пользовательского рейтинги платформ Xbox One и PC не подтвердилась.
# Гипотеза о равенстве пользовательского рейтинги жанра Action и  жанра Sports не была опровергнута.

# %% [markdown]
# <div class="alert-warning" style="padding: 20px; border-radius: 10px">
# <b>Комментарий ревьюера ⚠️</b>
#
# <s>Общий вывод в целом правильный. Но отдельные моменты нужно будет поправить, после доработки проекта, также можно добавить конкретики и цифр.
#
# Также не хватает рекомендаций магазину видеоигр, для которого мы проводили исследование. Подумай пожалуйста как их можно сформулировать, на каких платформах, жанрах и возрастных рейтингах, в каких регионах им нужно сконцентрироваться?</div>

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px; border-radius: 10px">
#
# <h5><b>🏁 Общий комментарий ревьюера</b></h5>
#
# Ты хорошо поработал над проектом. Но нужно кое-что поправить, чтобы я его принял.
#
# Критические замечания я добавил в меню **Contents** слева.
#
# Также, постарайся отработать желтые комментарии.
#
# Буду ждать твой доработанный проект. ⌛️

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px; border-radius: 10px">
#
# <h5><b>🏁 Общий комментарий ревьюера V2</b></h5>
#
# Спасибо, что дорабатываешь проект. У меня остались замечания:
#
# - по оформлению графиков, я хочу чтобы ты разобрался с названиями и подписями осей
# - по портретам пользователей в разрезе возрастного рейтинга
#
# Уверен, ты быстро все поправишь.
